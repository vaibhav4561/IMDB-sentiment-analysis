# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = [
    "I love red color",
    "I love blue color",
    "I love green color",
    "She drives a car",
    "She drives a bike",
    "She drives a bus",
]

# %%
sent
# Out:
# ['I love red color',
#  'I love blue color',
#  'I love green color',
#  'She drives a car',
#  'She drives a bike',
#  'She drives a bus']

# %%
## vocab size
voc_size = 10000

# %%
### one hot representation
one_hot_repr = [one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[6200, 4584, 4193, 1036],
#  [6200, 4584, 5159, 1036],
#  [6200, 4584, 942, 1036],
#  [1280, 1240, 5523, 5289],
#  [1280, 1240, 5523, 4183],
#  [1280, 1240, 5523, 2240]]

# %%
##word embedding representation

from tensorflow.keras.layers import Embedding
#from tensorflow.keras.processing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_len = 8
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_len)
print(embedded_docs)
# Out:
# [[   0    0    0    0 6200 4584 4193 1036]
#  [   0    0    0    0 6200 4584 5159 1036]
#  [   0    0    0    0 6200 4584  942 1036]
#  [   0    0    0    0 1280 1240 5523 5289]
#  [   0    0    0    0 1280 1240 5523 4183]
#  [   0    0    0    0 1280 1240 5523 2240]]

# %%
## feature representation

dim = 10 # dimension

# %%
model = Sequential()
model.add(Embedding(input_dim=voc_size, output_dim=dim, input_shape=(sent_len,)))
model.compile(optimizer="adam", loss="mse")

model.summary()
# Out:
# d:\Simple RNN\venv\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_11 (Embedding)        │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# array([[[-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01612852,  0.0037426 ,  0.03185945, -0.0470872 ,
#          -0.03497539, -0.02503668,  0.0034874 , -0.04107026,
#           0.00869324,  0.01329497],
#         [ 0.03418716,  0.0302887 ,  0.02158339, -0.00843854,
#          -0.04012209, -0.00303836, -0.01565192, -0.03385027,
#           0.01935582,  0.04289539],
#         [ 0.01043607, -0.00064594,  0.01455767,  0.00076034,
#           0.02866167, -0.02755177,  0.01561863,  0.01753889,
#          -0.02984411,  0.03044292],
#         [ 0.04849671, -0.03582263,  0.0379173 ,  0.00768967,
#           0.03101994,  0.04120586, -0.01967189, -0.04114232,
#          -0.0126225 ,  0.04072754]],
#
#        [[-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01612852,  0.0037426 ,  0.03185945, -0.0470872 ,
#          -0.03497539, -0.02503668,  0.0034874 , -0.04107026,
#           0.00869324,  0.01329497],
#         [ 0.03418716,  0.0302887 ,  0.02158339, -0.00843854,
#          -0.04012209, -0.00303836, -0.01565192, -0.03385027,
#           0.01935582,  0.04289539],
#         [ 0.00256839, -0.0234665 ,  0.00915817, -0.01989342,
#           0.02402935,  0.01859595,  0.0098582 , -0.01287072,
#           0.00399565,  0.03369465],
#         [ 0.04849671, -0.03582263,  0.0379173 ,  0.00768967,
#           0.03101994,  0.04120586, -0.01967189, -0.04114232,
#          -0.0126225 ,  0.04072754]],
#
#        [[-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01612852,  0.0037426 ,  0.03185945, -0.0470872 ,
#          -0.03497539, -0.02503668,  0.0034874 , -0.04107026,
#           0.00869324,  0.01329497],
#         [ 0.03418716,  0.0302887 ,  0.02158339, -0.00843854,
#          -0.04012209, -0.00303836, -0.01565192, -0.03385027,
#           0.01935582,  0.04289539],
#         [-0.00371163,  0.00265602,  0.02784263,  0.00838315,
#          -0.03168329,  0.04823175,  0.0465681 ,  0.04930153,
#           0.01504827, -0.04898926],
#         [ 0.04849671, -0.03582263,  0.0379173 ,  0.00768967,
#           0.03101994,  0.04120586, -0.01967189, -0.04114232,
#          -0.0126225 ,  0.04072754]],
#
#        [[-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01142249,  0.03444738,  0.01898111, -0.02265981,
#          -0.02038199,  0.00727588,  0.00711008, -0.03395271,
#          -0.02141615, -0.02335886],
#         [ 0.04451836,  0.03093762,  0.0242717 , -0.0183959 ,
#           0.01788611, -0.01131607, -0.01517042, -0.04784371,
#          -0.02554319,  0.0458906 ],
#         [ 0.04358664, -0.01572815,  0.04329488,  0.04002544,
#           0.04524741, -0.00367199, -0.00123184, -0.02922645,
#           0.00080433, -0.04453972],
#         [-0.01664034, -0.03777225, -0.02963845, -0.01832657,
#           0.04119266, -0.03609524,  0.04612117, -0.01936389,
#           0.03558549, -0.02807226]],
#
#        [[-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01142249,  0.03444738,  0.01898111, -0.02265981,
#          -0.02038199,  0.00727588,  0.00711008, -0.03395271,
#          -0.02141615, -0.02335886],
#         [ 0.04451836,  0.03093762,  0.0242717 , -0.0183959 ,
#           0.01788611, -0.01131607, -0.01517042, -0.04784371,
#          -0.02554319,  0.0458906 ],
#         [ 0.04358664, -0.01572815,  0.04329488,  0.04002544,
#           0.04524741, -0.00367199, -0.00123184, -0.02922645,
#           0.00080433, -0.04453972],
#         [-0.01403813,  0.00192187, -0.03213348, -0.03960494,
#           0.02648479, -0.00853424,  0.03153129, -0.04863993,
#          -0.00315638,  0.01422581]],
#
#        [[-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01142249,  0.03444738,  0.01898111, -0.02265981,
#          -0.02038199,  0.00727588,  0.00711008, -0.03395271,
#          -0.02141615, -0.02335886],
#         [ 0.04451836,  0.03093762,  0.0242717 , -0.0183959 ,
#           0.01788611, -0.01131607, -0.01517042, -0.04784371,
#          -0.02554319,  0.0458906 ],
#         [ 0.04358664, -0.01572815,  0.04329488,  0.04002544,
#           0.04524741, -0.00367199, -0.00123184, -0.02922645,
#           0.00080433, -0.04453972],
#         [ 0.03169103,  0.03545049, -0.03196877,  0.01499251,
#           0.0424623 , -0.00150999, -0.00588565, -0.00618169,
#          -0.03028705, -0.04354674]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 6200, 4584, 4193, 1036], dtype=int32)

# %%
x = np.array([embedded_docs[0]]) 
model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# array([[[-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01032714, -0.02953233, -0.03002586,  0.00182992,
#           0.00427812, -0.02315271, -0.03485892,  0.01493993,
#          -0.00635926, -0.01904482],
#         [-0.01612852,  0.0037426 ,  0.03185945, -0.0470872 ,
#          -0.03497539, -0.02503668,  0.0034874 , -0.04107026,
#           0.00869324,  0.01329497],
#         [ 0.03418716,  0.0302887 ,  0.02158339, -0.00843854,
#          -0.04012209, -0.00303836, -0.01565192, -0.03385027,
#           0.01935582,  0.04289539],
#         [ 0.01043607, -0.00064594,  0.01455767,  0.00076034,
#           0.02866167, -0.02755177,  0.01561863,  0.01753889,
#          -0.02984411,  0.03044292],
#         [ 0.04849671, -0.03582263,  0.0379173 ,  0.00768967,
#           0.03101994,  0.04120586, -0.01967189, -0.04114232,
#          -0.0126225 ,  0.04072754]]], dtype=float32)
